# %% [markdown]
# # Trabalho de ICD: Atividades Extraterrestres
# Limpando o dataframe:

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("./consolidated_weather_V03.csv")
df
# Out:
#       state             city  colour      shape  mday  month  year  hour  \
# 0        WA          Olympia     NaN  Formation    14     11  1997    21
# 1        WA          Olympia     NaN   Fireball    14     11  1997    21
# 2        WA          Olympia     NaN  Formation    14     11  1997    21
# 3        MD        Salisbury     NaN       Oval    24     11  1997     2
# 4        MD        Salisbury  YELLOW       Oval    24     11  1997     2
# ...     ...              ...     ...        ...   ...    ...   ...   ...
# 51865    AZ  Prescott Valley     NaN     Circle    28      1  2000    20
# 51866    CA           Covina     NaN      Light    27      1  2000    18
# 51867    WA          Seattle     NaN   Fireball    26      1  2000    19
# 51868    TX         Edinburg     NaN      Light    25      1  2000    19
# 51869    NM       Rio Rancho     NaN     Sphere    23      1  2000    15
#
#             id  pressure  ...     dewpt  thunder  fog    precip      wspd  \
# ...

# %% [markdown]
# O comando .info() nos trás uma descrição de cada coluna e assim podemos decidir com quias vamos trabalhar e se é possivel colunas e deixar o dataframe menor. Vamos analisar as colunas e depois limpar as linhas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51870 entries, 0 to 51869
# Data columns (total 27 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   state      51870 non-null  object
#  1   city       51870 non-null  object
#  2   colour     80 non-null     object
#  3   shape      51868 non-null  object
#  4   mday       51870 non-null  int64
#  5   month      51870 non-null  int64
#  6   year       51870 non-null  int64
#  7   hour       51870 non-null  int64
#  8   id         51631 non-null  float64
#  9   pressure   51659 non-null  float64
#  10  temp       51544 non-null  float64
#  11  hail       51870 non-null  int64
#  12  heatindex  3589 non-null   float64
#  13  windchill  8718 non-null   float64
#  14  rain       51870 non-null  int64
#  15  vis        51170 non-null  float64
#  16  wdire      51863 non-null  object
#  17  dewpt      51393 non-null  float64
#  18  thunder    51870 non-null  int64
# ...

# %%
df[['rain']].describe()
# Out:
#                rain
# count  51870.000000
# mean       0.021477
# std        0.144969
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df["hail"].value_counts()
# Out:
# hail
# 0    51870
# Name: count, dtype: int64

# %% [markdown]
# A parti de dois comandos .info() e .volue_counts() é possivel visualizar que a coluna não tem dado. Sendo assim podemos removelo do nosso dataframe.

# %%
df = df.drop('hail', axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51870 entries, 0 to 51869
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   state      51870 non-null  object
#  1   city       51870 non-null  object
#  2   colour     80 non-null     object
#  3   shape      51868 non-null  object
#  4   mday       51870 non-null  int64
#  5   month      51870 non-null  int64
#  6   year       51870 non-null  int64
#  7   hour       51870 non-null  int64
#  8   id         51631 non-null  float64
#  9   pressure   51659 non-null  float64
#  10  temp       51544 non-null  float64
#  11  heatindex  3589 non-null   float64
#  12  windchill  8718 non-null   float64
#  13  rain       51870 non-null  int64
#  14  vis        51170 non-null  float64
#  15  wdire      51863 non-null  object
#  16  dewpt      51393 non-null  float64
#  17  thunder    51870 non-null  int64
#  18  fog        51870 non-null  int64
# ...

# %% [markdown]
# Agora vamos remover as linhas duplicadas do dataframe, usando o comando .drop_duplicates())

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       state             city  colour      shape  mday  month  year  hour  \
# 0        WA          Olympia     NaN  Formation    14     11  1997    21
# 1        WA          Olympia     NaN   Fireball    14     11  1997    21
# 3        MD        Salisbury     NaN       Oval    24     11  1997     2
# 4        MD        Salisbury  YELLOW       Oval    24     11  1997     2
# 5        MS         Gulfport     NaN   Triangle    31     12  1997    17
# ...     ...              ...     ...        ...   ...    ...   ...   ...
# 51865    AZ  Prescott Valley     NaN     Circle    28      1  2000    20
# 51866    CA           Covina     NaN      Light    27      1  2000    18
# 51867    WA          Seattle     NaN   Fireball    26      1  2000    19
# 51868    TX         Edinburg     NaN      Light    25      1  2000    19
# 51869    NM       Rio Rancho     NaN     Sphere    23      1  2000    15
#
#             id  pressure  ...     dewpt  thunder  fog    precip      wspd  \
# ...

# %% [markdown]
# Nosso dataframe tinha 51870 linhas e agora temos 51830 linhas, ou aparições.

# %%
df.to_csv('novodf.csv')
