# %% [markdown]
# # Trabalho de ICD: UAP(Fenômenos Anômalos Não Identificados)
# *Professor: Yuri Malheiros Alunos: Vitoria, Simplicio, Daiellem, Bruno*

# %% [markdown]
# ### Parte 3:
# Na terceira parte do projeto nós temos por objetivo visualizar os dados atraves de graficos. Nós dividimos essa parte em 3 notebooks, esse e mais dois, e separamos os 3 dataframes para lidarmos da melhor forma com seus dados e podermos visualizar da melhor forma. Na fase anterior do projeto nós conhecemos nossos dataframes, os tipos de dados que vamos lidar e como vamos buscar responder as perguntas com esses dados e tambem analisar se há outros questionamentos ou outra visão sobre esse tema. Nesse primeiro notebook escolhemos o 3º dataframe para trabalharmos, iniciamos os graficos de barras:

# %%
import pandas as pd

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
import matplotlib.pyplot as plt

# %%
import plotly.express as px

# %%
df3= pd.read_csv("./df3.csv")

# %%
df3
# Out:
#        Unnamed: 0 state             city  colour      shape  mday  month  \
# 0               0    WA          Olympia     NaN  Formation    14     11
# 1               1    WA          Olympia     NaN   Fireball    14     11
# 2               3    MD        Salisbury     NaN       Oval    24     11
# 3               4    MD        Salisbury  YELLOW       Oval    24     11
# 4               5    MS         Gulfport     NaN   Triangle    31     12
# ...           ...   ...              ...     ...        ...   ...    ...
# 51825       51865    AZ  Prescott Valley     NaN     Circle    28      1
# 51826       51866    CA           Covina     NaN      Light    27      1
# 51827       51867    WA          Seattle     NaN   Fireball    26      1
# 51828       51868    TX         Edinburg     NaN      Light    25      1
# 51829       51869    NM       Rio Rancho     NaN     Sphere    23      1
#
#        year  hour       id  ...  heatindex  windchill       vis  wdire  \
# 0      1997    21      NaN  ...        NaN  -0.080112 -2.461666  South
# 1      1997    21      NaN  ...        NaN  -0.080112 -2.461666  South
# 2      1997     2      NaN  ...        NaN        NaN -0.493176  North
# 3      1997     2      NaN  ...        NaN        NaN -0.493176  North
# 4      1997    17      NaN  ...        NaN        NaN  2.868935    NNE
# ...     ...   ...      ...  ...        ...        ...       ...    ...
# 51825  2000    20  57531.0  ...        NaN  -0.192838  0.064273  South
# 51826  2000    18  57536.0  ...        NaN        NaN -0.771900  North
# 51827  2000    19  57543.0  ...        NaN        NaN  0.064273  North
# 51828  2000    19  57544.0  ...        NaN        NaN  0.064273    ESE
# 51829  2000    15  57549.0  ...        NaN        NaN  0.064273     NW
#
#           dewpt    precip      wspd       hum     wgust          conds
# 0     -0.867472       NaN -0.357641  1.598872       NaN          Clear
# 1     -0.867472       NaN -0.357641  1.598872       NaN          Clear
# 2     -0.464073       NaN -0.911239  0.980525       NaN  Mostly Cloudy
# 3     -0.464073       NaN -0.911239  0.980525       NaN  Mostly Cloudy
# 4     -0.968322       NaN  0.373899 -1.207476       NaN  Partly Cloudy
# ...         ...       ...       ...       ...       ...            ...
# 51825 -1.835629       NaN -0.357641 -0.731823       NaN          Clear
# 51826       NaN       NaN -0.911239       NaN       NaN          Clear
# 51827 -0.595177       NaN -0.911239  0.790264       NaN  Mostly Cloudy
# 51828  0.635190       NaN  0.373899  0.171916       NaN       Overcast
# 51829 -2.481068 -0.092084  0.917612 -2.539302 -0.640525          Clear
#
# [51830 rows x 22 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51830 entries, 0 to 51829
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  51830 non-null  int64
#  1   state       51830 non-null  object
#  2   city        51830 non-null  object
#  3   colour      70 non-null     object
#  4   shape       51828 non-null  object
#  5   mday        51830 non-null  int64
#  6   month       51830 non-null  int64
#  7   year        51830 non-null  int64
#  8   hour        51830 non-null  int64
#  9   id          51631 non-null  float64
#  10  pressure    51619 non-null  float64
#  11  temp        51504 non-null  float64
#  12  heatindex   3583 non-null   float64
#  13  windchill   8704 non-null   float64
#  14  vis         51130 non-null  float64
#  15  wdire       51823 non-null  object
#  16  dewpt       51354 non-null  float64
#  17  precip      2010 non-null   float64
#  18  wspd        51483 non-null  float64
#  19  hum         51353 non-null  float64
#  20  wgust       3272 non-null   float64
#  21  conds       51823 non-null  object
# dtypes: float64(11), int64(5), object(6)
# memory usage: 8.7+ MB

# %% [markdown]
# Podemos trabalhar com o histograma ou com o bar, vamos interpretar os dados e saber qual se adéqua a cada coluna:

# %%
plt.bar(df3.value_counts(df3["mday"]).index, df3.value_counts(df3["mday"]).values)
plt.title('Registros de UAP por dias do Mês(1997-2017)')
plt.xlabel('Dias do mês')
plt.ylabel('Registros de UAP')
# Out:
# Text(0, 0.5, 'Registros de UAP')

# %% [markdown]
# Usamos aqui o grafico de barras mais simples, através o do value_counts ele conta a frequencia dos valores unicos e gera o grafico.

# %%
plt.bar(df3.value_counts(df3["month"]).index, df3.value_counts(df3["month"]).values)
plt.title('Registros de UAP por meses do Ano(1997-2017)')
plt.xlabel('Meses')
plt.ylabel('Registros de UAP')
# Out:
# Text(0, 0.5, 'Registros de UAP')

# %%
plt.bar(df3.value_counts(df3["year"]).index, df3.value_counts(df3["year"]).values)
plt.title('Registros de UAP por Ano(1997-2017)')
plt.xlabel('Anos')
plt.ylabel('Registros de UAP')
# Out:
# Text(0, 0.5, 'Registros de UAP')

# %% [markdown]
# Agora temos uma visualização melhor dos nossos dados referente aos dias, meses e anos.

# %%
sns.histplot(df3['hour'], kde = 'True')
plt.title('Horario dos avistamentos de UAP (1997-2017)')
plt.xlabel('Hora')
plt.ylabel('Registros de UAP')
# Out:
# Text(0, 0.5, 'Registros de UAP')

# %% [markdown]
# Para as horas eu usei o histograma, histograma é basicamente um gráfico de barras para variaveis quatitativas, que são dividias em intervalos, e nos mostra a frequencia de dados que se tem em cada intervalo, o Kde é uma estimativa da densidade desses dados. Achamos interessante mostrar com as horas pois é possivel observar uma alta densidade nos horarios da noite.

# %%
plt.bar(df3.value_counts(df3["wdire"]).index, df3.value_counts(df3["wdire"]).values)
plt.title('Registros de UAP por localização Geografica(1997-2017)')
plt.xlabel('Orientação')
plt.ylabel('Registros de UAP')
plt.xticks(rotation='vertical')
plt.xticks(fontsize=7)
plt.figure(figsize=(5,5))

# %%
plt.figure(figsize=(7,3))
plt.xticks(fontsize=8)
plt.xticks(rotation=80)
sns.countplot(x='state',order=df3['state'].value_counts().index,data=df3)
plt.xlim(-0.5,9.5)
plt.title('Registros de UAP por Estados(1997-2017)')
plt.xlabel('Estados')
plt.ylabel('Registros de UAP')
# Out:
# Text(0, 0.5, 'Registros de UAP')

# %% [markdown]
# como o dataframe apresenta muitos valores unicos, como nas colunas cidade, estado e condições de tempo na hora das aparições, optei pelo grafico countplot, pois ele apresenta a propiedade de podermos escolher os n primeiros dados com maior valor.

# %%
plt.figure(figsize=(8,4))
plt.xticks(fontsize=8)
plt.xticks(rotation=80)
plt.title('10 Cidades com mais registros de UAP(1997-2017)')
plt.xlabel('Cidades')
plt.ylabel('Registros de UAP')
sns.countplot(x='city',order=df3['city'].value_counts().index,data=df3)
plt.xlim(-0.5,9.5)
# Out:
# (-0.5, 9.5)

# %%
plt.figure(figsize=(7,3))
plt.xticks(fontsize=6)
plt.xticks(rotation=80)
sns.countplot(x='conds',order=df3['conds'].value_counts().index,data=df3)
plt.title('Condições do tempo(1997-2017)')
plt.xlabel('Condições')
plt.ylabel('Registros de UAP')
plt.xlim(-0.5,9.5)
# Out:
# (-0.5, 9.5)

# %% [markdown]
# Os 4 graficos acima apresentam dados geograficos dos locais de aparições que vão ser utilizados em uma mapa no próximo notebook para uma observação mais detalhada. O ultimo grafico apresenta informações das condições climaticas na hora das observações, vaiser muito relevante para nossas proximas etapas.

# %%
plt.bar(df3.value_counts(df3["shape"]).index, df3.value_counts(df3["shape"]).values)
plt.title('Caracteristicas dos UAP(1997-2017)')
plt.xlabel('Morfologia')
plt.ylabel('Registros de UAP')
plt.xticks(rotation=75)
plt.xticks(fontsize=8)
plt.figure(figsize=(2,2))

# %%
plt.bar(df3.value_counts(df3["colour"]).index, df3.value_counts(df3["colour"]).values)
plt.title('Caracteristicas dos UAP(1997-2017)')
plt.xlabel('Cor')
plt.ylabel('Registros de UAP')
plt.xticks(rotation=80)
plt.xticks(fontsize=6)
plt.figure(figsize=(7,3))

# %% [markdown]
# Os dois ultimos graficos apresentam caracteristicas morfologicas dos UAP, tambem seram muito relevantes nas nossas interpretações para responder algumas questões.

# %% [markdown]
# O grafico de dispersão ou Scatter plot são representações gráficas do relacionamento entre duas variáveis numéricas. O Scatter plot utiliza pontos para representar essa relação, cada ponto representa o valor de uma variável no eixo horizontal e o valor de outra variável no eixo vertical. Vamos usar esse grafico para vê as relaçoes das colunas climaticas do nosso dataframe.

# %% [markdown]
# Logo abaixo fizemos um grafico de dispersão dos dias, meses e anos em relaçaõ a temperatura. Observamos dados normais, com alguns outlier, mas sem muita relavancia já que estamos falando de temperatura em relação ao tempo. Por exemplo no gráfico dos meses é possivel observar a variação da temperatura com os meses, explicando as estações do ano.

# %%
grafico = sns.scatterplot(data=df3, x="mday", y="temp")
grafico.set_title('Dias X Temperatura')
grafico.set_xlabel('Dia', fontsize=12)
grafico.set_ylabel('Temperatura', fontsize=12)
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
grafico2=sns.scatterplot(data=df3, x="month", y="temp")
grafico2.set_title('Meses X Temperatura')
grafico2.set_xlabel('Meses', fontsize=12)
grafico2.set_ylabel('Temperatura', fontsize=12)
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
grafico3 = sns.scatterplot(data=df3, x="year", y="temp")
grafico3.set_title('Ano X Temperatura')
grafico3.set_xlabel('Ano', fontsize=12)
grafico3.set_ylabel('Temperatura', fontsize=12)
# Out:
# Text(0, 0.5, 'Temperatura')

# %% [markdown]
# O grafico de dispersão é muito importante para algumas visualizaçãoes, mas para nós não fez muito sentido pelo nossos tipos de dados
