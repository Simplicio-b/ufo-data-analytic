# %% [markdown]
# # UAP (Fenômenos Anômalos não Identificados)

# %% [markdown]
# Bruno Marques Rodrigues,
# Daielem Leyssa Gonçalves do Nascimento,
# Simplicio Baiano de Souza Neto,
# Vitória Emanuele de Sousa Silva.

# %% [markdown]
# ## Relatório:

# %% [markdown]
# ### Introdução:

# %% [markdown]
# Motivação: A tarefa de examinar e estudar os UFO, ou atualmente UAP, sempre pareceu uma ideia conspiratória, o que a ciência não podia/pode explicar se mostrou a rota perfeita para discutir sobre os ETs. Durante muito tempo a Ufologia e a Ciência caminhavam em lados opostos, muito ligada ao fato de a Ciência ignorar relatos sobre avistamentos que teriam certo potencial para descredibilizá-la ou o questionamento da existência dos ETs, ou não, não parece ser importante. Atualmente a Ciência procurou dar uma seriedade ao tema e responder aos questionamentos da sociedade.
# &nbsp;
#
# Objetivo: O presente trabalho tem por objetivo analisar dados dos UAP, identificar padrões e buscar formas de identificar e responder sobre os Fenômenos.

# %% [markdown]
# ### Dados Usados e Pré-processamento:

# %% [markdown]
# Usamos três Datasets diferentes:

# %% [markdown]
# - O primeiro conta com 1317 linhas e 13 colunas. Registradas de 2014 a 2023, as colunas têm informações cronológicas(data e hora), informações geográficas(cidade, estado, latitude, longitude e população), morfologia dos UAP(forma), detalhes das observações(duração, sumario, imagens e link das imagens).
# ![image.png](attachment:image.png)
# Verificamos que não havia linhas duplicadas, colunas desnecessárias e tipo de variável para modificar. Em seguida salvamos esse dataframe com outro nome para facilitar a utilização e não nos perdemos ao longo das fases do projeto.
# [Fonte DataSet1](https://www.kaggle.com/datasets/joebeachcapital/ufo-sightings)

# %% [markdown]
# - O segundo conta com 70 anos de registros, são 80332 aparições de 1949 a 2019, dispostas em 11 colunas. As colunas tem dados geograficos(cidade, estado, País, Latitude, Longitude), morfologia dos UAP(forma), detalhes das observações(duração da observação, duração da descrição do encontro e descrição) e a data da documentação.
#
# ![image.png](attachment:image.png)
#
# Observamos que a latitude é um dado quantitativo, mas estava como object. Procuramos saber porque ele foi interpretado dessa forma e descobrimos que foi digitado uma letra entre os números, com essa informação usamos o replace para remover essa letra e  em seguida mudar o tipo da coluna para float.
#
# ![image-2.png](attachment:image-2.png)
#
# Depois salvamos o dataframe modificado.
# [Fonte DataSet2](https://www.kaggle.com/datasets/camnugent/ufo-sightings-around-the-world)

# %% [markdown]
# - O terceiro conta com 27 colunas e 51870 linhas. Primeiramente analisamos as colunas, pois notamos que era muitas. Percebemos que existia 6 colunas com nome de fenômenos naturais, utilizando de valores boleanos, e tem uma coluna chamada conds no dataframe, ou seja, as 6 colunas já estavam sendo especificado na coluna conds.
# ![image.png](attachment:image.png)
# Então tomamos a decisão de removê-las do dataframe.
# ![image-2.png](attachment:image-2.png)
# Depois removemos as linhas duplicadas. E salvamos esse dataframe com as modificações feitas. Esse dataframe tem informações de aparições de 10 anos de 1997 a 2017.
# [Fonte DataSet3](https://www.kaggle.com/datasets/emorelli/consolidated-ufo-weather-data)

# %% [markdown]
# ### Perguntas:

# %% [markdown]
# #### 1. Quais são as regiões com maior recorrência de aparições?

# %% [markdown]
# |DataFrame| Cidade | Estado | Pais | Região
# | :-: | :-: | :-: | :-: | :-:
# |1| Las Vegas | Florida | |
# |2| Seattle|  Califórnia | EUA |
# |3| Phoenix |  Califórnia | | Norte

# %% [markdown]
# Essa tabela conta com os dados dos três Dataframes, os três mostram que os Estados Unidos contam com o maior número de aparições. Logo abaixo esta a imagem de um dos gráficos que utilizamos na parte três do projeto (está nomeado como ProjetoPart3.1) e podemos notar que a America conta com a maioria das aparições.

# %% [markdown]
# ![newplot.png](attachment:newplot.png)

# %% [markdown]
# Fazendo uma análise por orientação geográfica dos dados da tabela: primeiro pela localização das cidades, Las Vegas fica no estado de Nevada Oeste dos EUA, em seguida Seattle localizada no Estado de Washington Noroeste do país e Phoenix que está localizada no Estado do Arizona Sudoeste dos EUA. Agora olhando pelos Estados temos a Florida localizada no Sudeste dos EUA e a Califórnia na Costa Oeste do País. Percebemos que Nevada, Washington, Arizona e Califórnia são todos Estados localizados ao norte, Costa do pacífico e muito próximos(Nevada, Arizona e Califórnia fazem fronteira). Também observamos pelo gráfico que as regiões próximas ao mar são mais propensas a terem observações.

# %% [markdown]
# #### 2. Existe alguma norma relevante nas aparições?

# %% [markdown]
# Fizemos uma análise dos nossos gráficos(parte 3 do projeto) para buscarmos alguma tipo de padrão. O único padrão observado foi os horários das aparições. Logo abaixo um gráfico retirado do terceiro dataframe(Parte três do projeto)

# %% [markdown]
# ![texto](data:image/png;base64,...)

# %% [markdown]
# Observamos que os horários da noite são os mais propensos a terem observações. Podemos levar isso como um padrão.

# %% [markdown]
# #### 3. Qual a probabilidade dos UAP serem ETs ?

# %% [markdown]
# Responderemos essa pergunta da maneira mais fundada possível. Procuramos informações além do que os dados nos mostra, buscamos compreender melhor do assunto através de ufologistas como os brasileiros Edison Boaventura e Ademar José Gevaerd, pesquisamos sobre organizações focadas nesse tema como a ASA(Americanos pela Segurança Aeroespacial) uma organização liderada por pilotos militares:

# %% [markdown]
# [Site da safeaerospace](https://www.safeaerospace.org/)

# %% [markdown]
# E coincidentemente o Escritório de Resolução de Anomalias (AARO) da NASA, criado em 2022, juntamente com o governo dos Estados Unidos, tornou públicos relatórios sobre UAP e disponibilizou um site, de coletar e amostra de dados disponível para toda a população.

# %% [markdown]
# [Site da AARO](https://www.aaro.mil/)

# %% [markdown]
# O diretor da AARO em sua entrevista apontou que um dos maiores problemas de se trabalhar com esses dados são suas interpretações e que eles podem ser facilmente distorcidos.  Vamos analisar os dados que temos sobre as características dos UAP. Logo abaixo uma tabela criada com os dados dos três dataframes:

# %% [markdown]
# |DataFrame| Cor | Forma
# | :-: | :-: | :-:
# |1||  Circular
# |2||  Luz
# |3| Vermelho |  Luz

# %% [markdown]
# Essas descrições frequentes dos UAP terem forma de Luz podem ser interpretadas de maneira meteorologia, principalmente uma luz vermelha. Usando as descrições do terceiro DataFrame e o gráfico das condições climáticas desse mesmo dataframe:

# %% [markdown]
# ![testo auternativo](data:image/png;base64,...)

# %% [markdown]
# Observamos que as condições na hora dos avistamentos eram na grande maioria claras e em segundo nublado. Não só a NASA, mas muitos Ufologistas destacam um fenômeno luminoso chamado sprite, que está relacionado a descarga elétrica gerando flashs por alguns milissegundos, se tornando iluminado e assumindo formas variadas.

# %% [markdown]
# ![imagem](https://www.apolo11.com/imagens/2020/sprite_vermelho_20200824-093826.jpg)

# %% [markdown]
# Logo uma luz vermelha em um dia nublado, ou mesmo em dias claros, podem facilmente ser ETs(ou não).

# %% [markdown]
# Existem muitos desses fenômenos presentes na nossa atmosfera sem que nós saibamos de suas existências e que podem ser facilmente interpretadas como ETs. Atualmente a ciência porta de equipamentos refinados que detectam esses fenômenos com dados específicos que podem ser usados para o treinamento de algoritmo de interpretação dos fenômenos e descarta aqueles gerados pela natureza, entregando dados dos outros fenômenos não identificados para um estudo mais aprofundado.

# %% [markdown]
# #### 4. Existe alguma forma de obtermos dados melhores sobre os UAP para responder se são ETs ou fenomenos meterologicos?

# %% [markdown]
# Essa é uma pergunta que provavelmente muitos estão tentando responder. Usando dos nossos dados nós vamos propor algumas soluções para essa pergunta.

# %% [markdown]
# No final do quarto notebook(ProjetoPart4) nós deixamos uma ideia de para que nosso gráfico de dispersão poderia servir. Com esse gráfico, e com aquele anterior, é possível notar um agrupamento de dados em algumas regiões.

# %% [markdown]
# ![textoalternativo](data:image/png;base64,...)

# %% [markdown]
# Não é possível prever onde e quando vão ocorrer as aparições, mas podemos monitorar uma região de grande frequência. Com uma amplitude grande existe a possibilidade de monitorar todo o planeta.

# %% [markdown]
# Com as ferramentas adequadas pode-se coletar dados mais precisos e separar os fenômenos meteorológicos dos UAP. Como foi comentando no final da pergunta anterior.

# %% [markdown]
# ### Conclusão:

# %% [markdown]
# Conseguimos através da análise dos dados encontrar regiões e horários de maior incidência de observações dos UAP e propomos algumas soluções para analisar os fenômenos e responder aos questionamentos da sociedade.
